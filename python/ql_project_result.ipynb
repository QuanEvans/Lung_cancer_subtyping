# %%
from gse_tools.gse import GSEs

# %%
filepath="./../data/GSE10245_family.soft.gz"
gse = GSEs(file_path=filepath)
# Out:
# 20-Nov-2022 15:29:44 INFO GEOparse - Parsing ./../data/GSE10245_family.soft.gz:
# 20-Nov-2022 15:29:44 DEBUG GEOparse - DATABASE: GeoMiame
# 20-Nov-2022 15:29:44 DEBUG GEOparse - SERIES: GSE10245
# 20-Nov-2022 15:29:44 DEBUG GEOparse - PLATFORM: GPL570
# c:\Users\QuanEvans\AppData\Local\Programs\Python\Python310\lib\site-packages\GEOparse\GEOparse.py:545: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   table_data = parse_table_data(gpl_soft)
# 20-Nov-2022 15:29:46 DEBUG GEOparse - SAMPLE: GSM258551
# 20-Nov-2022 15:29:46 DEBUG GEOparse - SAMPLE: GSM258552
# 20-Nov-2022 15:29:46 DEBUG GEOparse - SAMPLE: GSM258553
# 20-Nov-2022 15:29:46 DEBUG GEOparse - SAMPLE: GSM258554
# 20-Nov-2022 15:29:46 DEBUG GEOparse - SAMPLE: GSM258555
# 20-Nov-2022 15:29:46 DEBUG GEOparse - SAMPLE: GSM258556
# 20-Nov-2022 15:29:46 DEBUG GEOparse - SAMPLE: GSM258557
# 20-Nov-2022 15:29:46 DEBUG GEOparse - SAMPLE: GSM258558
# 20-Nov-2022 15:29:46 DEBUG GEOparse - SAMPLE: GSM258559
# 20-Nov-2022 15:29:46 DEBUG GEOparse - SAMPLE: GSM258560
# 20-Nov-2022 15:29:46 DEBUG GEOparse - SAMPLE: GSM258561
# 20-Nov-2022 15:29:46 DEBUG GEOparse - SAMPLE: GSM258562
# 20-Nov-2022 15:29:46 DEBUG GEOparse - SAMPLE: GSM258563
# 20-Nov-2022 15:29:47 DEBUG GEOparse - SAMPLE: GSM258564
# 20-Nov-2022 15:29:47 DEBUG GEOparse - SAMPLE: GSM258565
# 20-Nov-2022 15:29:47 DEBUG GEOparse - SAMPLE: GSM258566
# 20-Nov-2022 15:29:47 DEBUG GEOparse - SAMPLE: GSM258567
# 20-Nov-2022 15:29:47 DEBUG GEOparse - SAMPLE: GSM258568
# 20-Nov-2022 15:29:47 DEBUG GEOparse - SAMPLE: GSM258569
# 20-Nov-2022 15:29:47 DEBUG GEOparse - SAMPLE: GSM258570
# 20-Nov-2022 15:29:47 DEBUG GEOparse - SAMPLE: GSM258571
# 20-Nov-2022 15:29:47 DEBUG GEOparse - SAMPLE: GSM258572
# 20-Nov-2022 15:29:47 DEBUG GEOparse - SAMPLE: GSM258573
# 20-Nov-2022 15:29:47 DEBUG GEOparse - SAMPLE: GSM258574
# 20-Nov-2022 15:29:47 DEBUG GEOparse - SAMPLE: GSM258575
# 20-Nov-2022 15:29:47 DEBUG GEOparse - SAMPLE: GSM258576
# 20-Nov-2022 15:29:47 DEBUG GEOparse - SAMPLE: GSM258577
# 20-Nov-2022 15:29:48 DEBUG GEOparse - SAMPLE: GSM258578
# 20-Nov-2022 15:29:48 DEBUG GEOparse - SAMPLE: GSM258579
# 20-Nov-2022 15:29:48 DEBUG GEOparse - SAMPLE: GSM258580
# 20-Nov-2022 15:29:48 DEBUG GEOparse - SAMPLE: GSM258581
# 20-Nov-2022 15:29:48 DEBUG GEOparse - SAMPLE: GSM258582
# 20-Nov-2022 15:29:48 DEBUG GEOparse - SAMPLE: GSM258583
# 20-Nov-2022 15:29:48 DEBUG GEOparse - SAMPLE: GSM258584
# 20-Nov-2022 15:29:48 DEBUG GEOparse - SAMPLE: GSM258585
# 20-Nov-2022 15:29:48 DEBUG GEOparse - SAMPLE: GSM258586
# 20-Nov-2022 15:29:48 DEBUG GEOparse - SAMPLE: GSM258587
# 20-Nov-2022 15:29:48 DEBUG GEOparse - SAMPLE: GSM258588
# 20-Nov-2022 15:29:48 DEBUG GEOparse - SAMPLE: GSM258589
# 20-Nov-2022 15:29:48 DEBUG GEOparse - SAMPLE: GSM258590
# 20-Nov-2022 15:29:48 DEBUG GEOparse - SAMPLE: GSM258591
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258592
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258593
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258594
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258595
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258596
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258597
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258598
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258599
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258600
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258601
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258602
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258603
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258604
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258605
# 20-Nov-2022 15:29:49 DEBUG GEOparse - SAMPLE: GSM258606
# 20-Nov-2022 15:29:50 DEBUG GEOparse - SAMPLE: GSM258607
# 20-Nov-2022 15:29:50 DEBUG GEOparse - SAMPLE: GSM258608

# %%
gse.set_seed(575)
gse.train_model().predict(testOnTrain=TRUE).accuracy#(i) train the model on all the data and compute the accuracy of the model on that data
# Out:
# 0.896551724137931

# %%
gse.train_model(n_clusters=2,train_frac=0.5).predict(testOnTrain=True).accuracy #(ii) train the model on half of the data and compute the accuracy of the model on that data
# Out:
# 0.9482758620689655

# %%
gse.train_model(n_clusters=2, train_frac=0.5).predict().accuracy #(iii) compute the model accuracy built at point (ii) on the other half of the data (test data)
# Out:
# 0.9655172413793104

# %%
gse.barplot_accuracy()

# %%
gse.scatter_pca()
